# %% [markdown]
# <a href="https://colab.research.google.com/github/DanielBUBU/bigdata-class/blob/master/assessment_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
install.packages("rJava")
install.packages("jiebaR")
install.packages("tmcn")
install.packages("dplyr")
install.packages("lubridate")
install.packages("stringr")
install.packages("wordcloud")
install.packages("Rwordseg",repo="http://R-Forge.R-project.org")
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependency ‘jiebaRD’
#
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# Warning message:
# “dependency ‘HMM’ is not available”
# Warning message in install.packages("Rwordseg", repo = "http://R-Forge.R-project.org"):
# “installation of package ‘Rwordseg’ had non-zero exit status”

# %%
library(dplyr)
library(lubridate)
library(stringr)
library(jiebaR)
library(wordcloud)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
#
# Attaching package: ‘lubridate’
#
#
# The following objects are masked from ‘package:base’:
#
#     date, intersect, setdiff, union
#
#
# Loading required package: jiebaRD
#
# Loading required package: RColorBrewer

# %%
content <- "台灣東洋藥品公司日前取得德國BioNTech（ＢＮＴ）新冠疫苗在台銷售「有條件授權書」，但昨晚宣布協商破局。破局原因兜不攏，台灣東洋說，是ＢＮＴ與衛福部對疫苗數量與價格談不攏，無法如期代理疫苗進口；中央流行疫情指揮中心則說，東洋無法提供正式授權書及合約草案，談判無以為繼。

不過，指揮中心發言人莊人祥說，台灣東洋談判破局，不代表明年第一季沒疫苗可打，也不表示買不到ＢＮＴ新冠疫苗，指揮中心會繼續透過COVAX爭取ＢＮＴ新冠疫苗及其他國際疫苗，也會嘗試多種管道，積極與跟國際廠接洽，並持續支持國產疫苗。莊人祥強調：「我們沒有放棄任何一家疫苗」。

但前疾管局長蘇益仁說，國內明年三月前有疫苗可打的機會渺茫，預估國產疫苗明年六月上市，如今秋冬到來，新冠肺炎及流感疫情齊來，台灣已錯過十二月接種流感疫苗、明年一月、二月打新冠肺炎最理想的防疫模式。與東洋談判破局，讓明年第一季買到新冠肺炎疫苗可能性更小，對台灣來說選擇愈來愈少。

台灣疫苗推動協會理事長、長庚兒童感染科主治醫師黃玉成也說，即使簽了COVAX，但還是不確定能否爭取到疫苗，台灣若無法在第一季取得疫苗，各國陸續開打、邊境解封，國內還是只能高規格防疫，會對經濟造成衝擊。

台灣東洋說，上月取得ＢＮＴ授權後，積極扮演ＢＮＴ與政府間橋梁，討論最新臨床數據、採購數量、價格、冷鏈運送方式，但政府與ＢＮＴ在採購數量及價格上仍有落差，截至授權協商期滿，未達成共識。

莊人祥說，指揮中心已與東洋達到「願意談的數量」共識，破局是指揮中心要求台灣東洋提供正式授權文件及合約草案，「但他們一直無法提供」，指揮中心不解為何東洋連最基本的關鍵文件都不提供，後續評估做不下去。

台灣東洋回應，十月十二日發布重訊及記者會時，已清楚揭露取得ＢＮＴ「有條件授權」，並供疾管署備查。與政府協商期間，雖積極爭取延長ＢＮＴ授權期限，但部分商業條件未達成，才無法繼續提供有效證明文件。

另外，指揮中心昨宣布，國內又新增四名境外移入病例，分別自法國、英國、德國、菲律賓，其中三人為台灣留學生、一人為菲律賓境外生，已累計五六七例。"
cutter <- worker(bylines = F)

# %%
cutter[content]
# Out:
#   [1] "台灣"     "東洋"     "藥品"     "公司"     "日前"     "取得"
#   [7] "德國"     "BioNTech" "新"       "冠"       "疫苗"     "在"
#  [13] "台"       "銷售"     "有"       "條件"     "授權書"   "但"
#  [19] "昨晚"     "宣布"     "協商"     "破局"     "破局"     "原因"
#  [25] "兜"       "不攏"     "台灣"     "東洋"     "說"       "是"
#  [31] "與"       "衛"       "福"       "部"       "對"       "疫苗"
#  [37] "數量"     "與"       "價格"     "談不攏"   "無法"     "如期"
#  [43] "代理"     "疫苗"     "進口"     "中央"     "流行"     "疫情"
#  [49] "指揮中心" "則說"     "東洋"     "無法"     "提供"     "正式"
#  [55] "授權書"   "及"       "合約"     "草案"     "談判"     "無以"
#  [61] "為繼"     "不過"     "指揮中心" "發言人"   "莊人祥"   "說"
#  [67] "台灣"     "東洋"     "談判"     "破局"     "不"       "代表"
#  [73] "明年"     "第一季"   "沒"       "疫苗"     "可"       "打"
#  [79] "也"       "不"       "表示"     "買不到"   "新"       "冠"
#  [85] "疫苗"     "指揮中心" "會"       "繼續"     "透過"     "COVAX"
#  [91] "爭取"     "新"       "冠"       "疫苗"     "及其"     "他"
#  [97] "國際"     "疫苗"     "也"       "會"       "嘗試"     "多種"
# ...

# %%
new_words <- c("傳染性肺炎","醫療體系","防疫措施","東洋藥品公司","新冠","在台","兜不攏","衛服部")

for(i in 1:length(new_words))
{
  new_user_word(cutter,new_words[i])
}

content <- str_remove_all(content,"[0-9a-zA-Z]+?")
cutter[content]
# Out:
#   [1] "台灣"         "東洋藥品公司" "日前"         "取得"         "德國"
#   [6] "新冠"         "疫苗"         "在台"         "銷售"         "有"
#  [11] "條件"         "授權書"       "但"           "昨晚"         "宣布"
#  [16] "協商"         "破局"         "破局"         "原因"         "兜不攏"
#  [21] "台灣"         "東洋"         "說"           "是"           "與"
#  [26] "衛"           "福"           "部"           "對"           "疫苗"
#  [31] "數量"         "與"           "價格"         "談不攏"       "無法"
#  [36] "如期"         "代理"         "疫苗"         "進口"         "中央"
#  [41] "流行"         "疫情"         "指揮中心"     "則說"         "東洋"
#  [46] "無法"         "提供"         "正式"         "授權書"       "及"
#  [51] "合約"         "草案"         "談判"         "無以"         "為繼"
#  [56] "不過"         "指揮中心"     "發言人"       "莊人祥"       "說"
#  [61] "台灣"         "東洋"         "談判"         "破局"         "不"
#  [66] "代表"         "明年"         "第一季"       "沒"           "疫苗"
#  [71] "可"           "打"           "也"           "不"           "表示"
# ...

# %%
writeLines(new_words,"new_words.txt")
stop_words <- c("在","之","更","個","未","而","也","的","與","說")
writeLines(stop_words,"stop_words.txt")

cutter <- worker(user = "new_words.txt",stop_word = "stop_words.txt",bylines = FALSE)
seg_words <- cutter[content]
seg_words
# Out:
#   [1] "台灣"         "東洋藥品公司" "日前"         "取得"         "德國"
#   [6] "新冠"         "疫苗"         "在台"         "銷售"         "有"
#  [11] "條件"         "授權書"       "但"           "昨晚"         "宣布"
#  [16] "協商"         "破局"         "破局"         "原因"         "兜不攏"
#  [21] "台灣"         "東洋"         "是"           "衛"           "福"
#  [26] "部"           "對"           "疫苗"         "數量"         "價格"
#  [31] "談不攏"       "無法"         "如期"         "代理"         "疫苗"
#  [36] "進口"         "中央"         "流行"         "疫情"         "指揮中心"
#  [41] "則說"         "東洋"         "無法"         "提供"         "正式"
#  [46] "授權書"       "及"           "合約"         "草案"         "談判"
#  [51] "無以"         "為繼"         "不過"         "指揮中心"     "發言人"
#  [56] "莊人祥"       "台灣"         "東洋"         "談判"         "破局"
#  [61] "不"           "代表"         "明年"         "第一季"       "沒"
#  [66] "疫苗"         "可"           "打"           "不"           "表示"
#  [71] "買不到"       "新冠"         "疫苗"         "指揮中心"     "會"
# ...

# %%
txt_freq <- freq(seg_words)
txt_freq <- arrange(txt_freq,desc(freq))
head(txt_freq)
# Out:
#   char     freq
# 1 疫苗     15
# 2 台灣     11
# 3 東洋      9
# 4 指揮中心  7
# 5 新冠      6
# 6 明年      5

# %%
install.packages("showtext")
library(showtext)
showtext.auto(enable = TRUE)
# Out:
# Installing package into ‘/usr/local/lib/R/site-library’
# (as ‘lib’ is unspecified)
#
# also installing the dependencies ‘sysfonts’, ‘showtextdb’
#
#
# Loading required package: sysfonts
#
# Loading required package: showtextdb
#
# 'showtext.auto()' is now renamed to 'showtext_auto()'
# The old version still works, but consider using the new function in future code

# %%
par(family = ("Microsoft YaHei"))

wordcloud(txt_freq$char,txt_freq$freq,min.freq = 2,random.order = F,ordered.colors = F,colors = rainbow(nrow(txt_freq)))
# Out:
# Warning message in strwidth(words[i], cex = size[i], ...):
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in strheight(words[i], cex = size[i], ...):
# “font family 'Microsoft YaHei' not found, will use 'sans' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# Warning message in text.default(x1, y1, words[i], cex = size[i], offset = 0, srt = rotWord * :
# “font family 'Microsoft YaHei' not found, will use 'wqy-microhei' instead”
# ...
